# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import folium
import geopandas as gpd
import json
import altair as alt
# Enable Altair's data transformer for handling large datasets
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# # Folium

# %% [markdown]
# ## Base map

# %%
# Create a map centered on Pisa
m = folium.Map(
    location=[43.702, 10.396],  # [latitudine, longitudine]
    zoom_start=13,              # Initial zoom level
    tiles='OpenStreetMap',      # Provider of the map tiles
    control_scale=True          # Show scale control
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cc91bdd95e0648f0f4385fd1c5f18e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cc91bdd95e0648f0f4385fd1c5f18e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7cc91bdd95e0648f0f4385fd1c5f18e7 = L.map(
#                 &quot;map_7cc91bdd95e0648f0f4385fd1c5f18e7&quot;,
#                 {
#                     center: [43.702, 10.396],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_7cc91bdd95e0648f0f4385fd1c5f18e7);
#
#
#
#
#
#             var tile_layer_d5ea5714bc185f9d8647758dd2dfea7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5ea5714bc185f9d8647758dd2dfea7d.addTo(map_7cc91bdd95e0648f0f4385fd1c5f18e7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Tile layers

# %%
# Map with terrain style
m_terrain = folium.Map(
    location=[43.702, 10.396],
    zoom_start=13,
    tiles='CartoDB dark_matter'
)

# %%
# Map with multiple tile layers
m = folium.Map(
    location=[43.702, 10.396],
    zoom_start=13
)

# Add different tile layers
folium.TileLayer('CartoDB dark_matter', name='Scuro').add_to(m)
folium.TileLayer('CartoDB positron', name='Chiaro').add_to(m)
# Add a layer control icon
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c799a0a781e64190d83cef33b0380d5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c799a0a781e64190d83cef33b0380d5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c799a0a781e64190d83cef33b0380d5e = L.map(
#                 &quot;map_c799a0a781e64190d83cef33b0380d5e&quot;,
#                 {
#                     center: [43.702, 10.396],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d11a667173cefbc6291118c6718ddb2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d11a667173cefbc6291118c6718ddb2e.addTo(map_c799a0a781e64190d83cef33b0380d5e);
#
#
#             var tile_layer_df60fcb825c296b829e23d6911debc19 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df60fcb825c296b829e23d6911debc19.addTo(map_c799a0a781e64190d83cef33b0380d5e);
#
#
#             var tile_layer_0f6350adff7c95f9267d088e223ea5b1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f6350adff7c95f9267d088e223ea5b1.addTo(map_c799a0a781e64190d83cef33b0380d5e);
#
#
#             var layer_control_5a98249450f2415d524e3361dfe2387d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d11a667173cefbc6291118c6718ddb2e,
#                     &quot;Scuro&quot; : tile_layer_df60fcb825c296b829e23d6911debc19,
#                     &quot;Chiaro&quot; : tile_layer_0f6350adff7c95f9267d088e223ea5b1,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_5a98249450f2415d524e3361dfe2387d = L.control.layers(
#                 layer_control_5a98249450f2415d524e3361dfe2387d_layers.base_layers,
#                 layer_control_5a98249450f2415d524e3361dfe2387d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c799a0a781e64190d83cef33b0380d5e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Additional layer styles: [link](https://python-visualization.github.io/folium/latest/user_guide/raster_layers/tiles.html)

# %% [markdown]
# ## Markers and geometries

# %%
# Create a map centered on Pisa
m = folium.Map(location=[43.702, 10.396], zoom_start=13)

# %% [markdown]
# ### Add a marker with a popup

# %%
# Add a marker
folium.Marker(
    location=[43.7186, 10.39],
    popup='<b>Pisa Tower</b>',
    tooltip='Click for more info',
    icon=folium.Icon(icon='info-sign', color='red')
).add_to(m)

# %% [markdown]
# ### Add geometries

# %%
# Add a circle
folium.Circle(
    location=[43.6890, 10.3977],
    radius=100,  # raggio in metri
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=0.2,
    popup='Pisa Airport',
).add_to(m)

# Add a polygon
coordinates = [
    [43.7213, 10.3963],  # [lat, lon]
    [43.7225, 10.3995],
    [43.7196, 10.4007],
    [43.7186, 10.3973]
]

folium.Polygon(
    locations=coordinates,
    color='green',
    fill=True,
    fill_color='green',
    fill_opacity=0.4,
    popup='Area del centro storico'
).add_to(m)

# Add a polyline
folium.PolyLine(
    locations=[[43.7186, 10.3976], [43.7223, 10.3970], [43.7210, 10.3995], [43.7186, 10.421]],
    color='red',
    weight=3,
    opacity=0.7,
    popup='Percorso turistico'
).add_to(m)

# %% [markdown]
# ### Visualize the map

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88357956901d673ab5c49958210931c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88357956901d673ab5c49958210931c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88357956901d673ab5c49958210931c2 = L.map(
#                 &quot;map_88357956901d673ab5c49958210931c2&quot;,
#                 {
#                     center: [43.702, 10.396],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_034c98ac0ceb7639e9d8e190cc4f631a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_034c98ac0ceb7639e9d8e190cc4f631a.addTo(map_88357956901d673ab5c49958210931c2);
#
#
#             var marker_ace93ea109aac0041ab8e9f746ffe91c = L.marker(
#                 [43.7186, 10.39],
#                 {
# }
#             ).addTo(map_88357956901d673ab5c49958210931c2);
#
#
#             var icon_a5f8ebbad7ee3aff57db53d43f17cc4e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ce262e88b5f046ed93ca00be323e22d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68c13569db76cdf6a3c97eb5b4c08db4 = $(`&lt;div id=&quot;html_68c13569db76cdf6a3c97eb5b4c08db4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Pisa Tower&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_ce262e88b5f046ed93ca00be323e22d3.setContent(html_68c13569db76cdf6a3c97eb5b4c08db4);
#
#
#
#         marker_ace93ea109aac0041ab8e9f746ffe91c.bindPopup(popup_ce262e88b5f046ed93ca00be323e22d3)
#         ;
#
#
#
#
#             marker_ace93ea109aac0041ab8e9f746ffe91c.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ace93ea109aac0041ab8e9f746ffe91c.setIcon(icon_a5f8ebbad7ee3aff57db53d43f17cc4e);
#
#
#             var circle_cb67bc177286e40e0b437cd447a91b70 = L.circle(
#                 [43.689, 10.3977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88357956901d673ab5c49958210931c2);
#
#
#         var popup_9b9b0dd232289c90ada0c5557bd23dfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cab156ecd9ea3b180190648a7cdc91b = $(`&lt;div id=&quot;html_4cab156ecd9ea3b180190648a7cdc91b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pisa Airport&lt;/div&gt;`)[0];
#                 popup_9b9b0dd232289c90ada0c5557bd23dfe.setContent(html_4cab156ecd9ea3b180190648a7cdc91b);
#
#
#
#         circle_cb67bc177286e40e0b437cd447a91b70.bindPopup(popup_9b9b0dd232289c90ada0c5557bd23dfe)
#         ;
#
#
#
#
#             var polygon_c5cbf07bec71605b113347aa299e508f = L.polygon(
#                 [[43.7213, 10.3963], [43.7225, 10.3995], [43.7196, 10.4007], [43.7186, 10.3973]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88357956901d673ab5c49958210931c2);
#
#
#         var popup_f93bd2eba8817e2cfe3b7e2ac7817e80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af860c279a1ce387d3edb7390a1bae2c = $(`&lt;div id=&quot;html_af860c279a1ce387d3edb7390a1bae2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area del centro storico&lt;/div&gt;`)[0];
#                 popup_f93bd2eba8817e2cfe3b7e2ac7817e80.setContent(html_af860c279a1ce387d3edb7390a1bae2c);
#
#
#
#         polygon_c5cbf07bec71605b113347aa299e508f.bindPopup(popup_f93bd2eba8817e2cfe3b7e2ac7817e80)
#         ;

# %% [markdown]
# # Folium: Advanced Customization

# %%
import folium
from folium.plugins import MiniMap, Fullscreen, LocateControl, MousePosition

# Create a basic map
m = folium.Map(location=[43.72, 10.40], zoom_start=14)

# Add 3 different markers (Point of interest, Station, Park)
folium.Marker(
    location=[43.725, 10.4003],
    popup='Punto di interesse',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Marker(
    location=[43.707, 10.3980],
    popup='Stazione',
    icon=folium.Icon(color='blue', icon='info-sign')
).add_to(m)
folium.Marker(
    location=[43.7116, 10.4072],
    popup='Parco',
    icon=folium.Icon(color='green', icon='info-sign')
).add_to(m)

# Add a MiniMap
MiniMap().add_to(m)

# Add a Fullscreen button
Fullscreen().add_to(m)

# Control for locating the user
LocateControl().add_to(m)

# Show mouse position coordinates
MousePosition().add_to(m)

# Add a custom legend
legend_html = '''
<div style="position: fixed;
     bottom: 50px; left: 50px; width: 150px; height: 120px;
     background-color: white; border:2px solid grey; z-index:9999; font-size:14px;
     padding: 10px;">
     <b>Legenda</b><br>
     <i class="fa fa-circle" style="color:red"></i> Punti di interesse<br>
     <i class="fa fa-circle" style="color:blue"></i> Stazioni<br>
     <i class="fa fa-circle" style="color:green"></i> Parchi
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51fd8df0508bc1f445b484945de62dfb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      bottom: 50px; left: 50px; width: 150px; height: 120px;
#      background-color: white; border:2px solid grey; z-index:9999; font-size:14px;
#      padding: 10px;&quot;&gt;
#      &lt;b&gt;Legenda&lt;/b&gt;&lt;br&gt;
#      &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt; Punti di interesse&lt;br&gt;
#      &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt; Stazioni&lt;br&gt;
#      &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt; Parchi
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51fd8df0508bc1f445b484945de62dfb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51fd8df0508bc1f445b484945de62dfb = L.map(
#                 &quot;map_51fd8df0508bc1f445b484945de62dfb&quot;,
#                 {
#                     center: [43.72, 10.4],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74f67d6a87b9435e275b74d1c0f750ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74f67d6a87b9435e275b74d1c0f750ec.addTo(map_51fd8df0508bc1f445b484945de62dfb);
#
#
#             var marker_f9751ca10d63273be42d07ae1bee3da1 = L.marker(
#                 [43.725, 10.4003],
#                 {
# }
#             ).addTo(map_51fd8df0508bc1f445b484945de62dfb);
#
#
#             var icon_a1cd9147fcc2ad9456341aae2c60de8c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c305616633640c1288713d8b3e11f3c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dbc9003c6e8c60b9fdd021f14681c31 = $(`&lt;div id=&quot;html_8dbc9003c6e8c60b9fdd021f14681c31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto di interesse&lt;/div&gt;`)[0];
#                 popup_c305616633640c1288713d8b3e11f3c5.setContent(html_8dbc9003c6e8c60b9fdd021f14681c31);
#
#
#
#         marker_f9751ca10d63273be42d07ae1bee3da1.bindPopup(popup_c305616633640c1288713d8b3e11f3c5)
#         ;
#
#
#
#
#                 marker_f9751ca10d63273be42d07ae1bee3da1.setIcon(icon_a1cd9147fcc2ad9456341aae2c60de8c);
#
#
#             var marker_df45677643b859f62001e4751d8f152d = L.marker(
#                 [43.707, 10.398],
#                 {
# }
#             ).addTo(map_51fd8df0508bc1f445b484945de62dfb);
#
#
#             var icon_79355e60b1dc969b203b3cdb444ae493 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f98c3eb753cb40f88c1023cbece6e0f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_519c92e49bfcfbad320b5ae3081e45a3 = $(`&lt;div id=&quot;html_519c92e49bfcfbad320b5ae3081e45a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stazione&lt;/div&gt;`)[0];
#                 popup_f98c3eb753cb40f88c1023cbece6e0f6.setContent(html_519c92e49bfcfbad320b5ae3081e45a3);
#
#
#
#         marker_df45677643b859f62001e4751d8f152d.bindPopup(popup_f98c3eb753cb40f88c1023cbece6e0f6)
#         ;

# %% [markdown]
# # Marker clustering

# %%
from folium.plugins import MarkerCluster

# Example data
data = pd.DataFrame({
    'lat': [43.7186, 43.7210, 43.7225, 43.7190, 43.7185, 43.7195],
    'lon': [10.3976, 10.3980, 10.3995, 10.4005, 10.4010, 10.3990],
    'name': ['Punto A', 'Punto B', 'Punto C', 'Punto D', 'Punto E', 'Punto F']
})

# Base map
m = folium.Map(location=[43.720, 10.399], tiles='CartoDB positron', zoom_start=15)

# Create a marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Add all points to the marker cluster
for idx, row in data.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=row['name']
    ).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3af7dc7a9ceb5891a522a25bbbdc4e27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3af7dc7a9ceb5891a522a25bbbdc4e27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3af7dc7a9ceb5891a522a25bbbdc4e27 = L.map(
#                 &quot;map_3af7dc7a9ceb5891a522a25bbbdc4e27&quot;,
#                 {
#                     center: [43.72, 10.399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_019d3441504cab4721c77caf5a9758f2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_019d3441504cab4721c77caf5a9758f2.addTo(map_3af7dc7a9ceb5891a522a25bbbdc4e27);
#
#
#             var marker_cluster_c22956838da34f80c48a155520380f4f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b691f695a94d21a3905d4f479b6479e9 = L.marker(
#                 [43.7186, 10.3976],
#                 {
# }
#             ).addTo(marker_cluster_c22956838da34f80c48a155520380f4f);
#
#
#         var popup_9bca0d79aa107e7436fea5c9783b7424 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37587bff85fea5bb4a638055d4ba9d76 = $(`&lt;div id=&quot;html_37587bff85fea5bb4a638055d4ba9d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto A&lt;/div&gt;`)[0];
#                 popup_9bca0d79aa107e7436fea5c9783b7424.setContent(html_37587bff85fea5bb4a638055d4ba9d76);
#
#
#
#         marker_b691f695a94d21a3905d4f479b6479e9.bindPopup(popup_9bca0d79aa107e7436fea5c9783b7424)
#         ;
#
#
#
#
#             var marker_e13c2fc460c31fcfb4b661bbc4ab43ec = L.marker(
#                 [43.721, 10.398],
#                 {
# }
#             ).addTo(marker_cluster_c22956838da34f80c48a155520380f4f);
#
#
#         var popup_4a0a4904b7fc7e7c30d9293e46b87a65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d87fc432453bcaecf25e19e6f1c8eab1 = $(`&lt;div id=&quot;html_d87fc432453bcaecf25e19e6f1c8eab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto B&lt;/div&gt;`)[0];
#                 popup_4a0a4904b7fc7e7c30d9293e46b87a65.setContent(html_d87fc432453bcaecf25e19e6f1c8eab1);
#
#
#
#         marker_e13c2fc460c31fcfb4b661bbc4ab43ec.bindPopup(popup_4a0a4904b7fc7e7c30d9293e46b87a65)
#         ;
#
#
#
#
#             var marker_3b7d5355f9200e7a0eec7c485de77cd1 = L.marker(
#                 [43.7225, 10.3995],
#                 {
# }
#             ).addTo(marker_cluster_c22956838da34f80c48a155520380f4f);
#
#
#         var popup_89c76f20fe3b9aa7b39b7c9d611c2b2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e2b2c7cdc95d02d961c5002836c90d7 = $(`&lt;div id=&quot;html_7e2b2c7cdc95d02d961c5002836c90d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto C&lt;/div&gt;`)[0];
#                 popup_89c76f20fe3b9aa7b39b7c9d611c2b2e.setContent(html_7e2b2c7cdc95d02d961c5002836c90d7);
#
#
#
#         marker_3b7d5355f9200e7a0eec7c485de77cd1.bindPopup(popup_89c76f20fe3b9aa7b39b7c9d611c2b2e)
#         ;
#
#
#
#
#             var marker_5f1b7fc3f9f361bd02b5e24ee6b773b3 = L.marker(
#                 [43.719, 10.4005],
#                 {
# }
#             ).addTo(marker_cluster_c22956838da34f80c48a155520380f4f);
#
#
#         var popup_dbe0f338ff4898016053b0135a71e185 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fe2edef7ca90943b6bcd5029c9a41a2 = $(`&lt;div id=&quot;html_2fe2edef7ca90943b6bcd5029c9a41a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto D&lt;/div&gt;`)[0];
#                 popup_dbe0f338ff4898016053b0135a71e185.setContent(html_2fe2edef7ca90943b6bcd5029c9a41a2);
#
#
#
#         marker_5f1b7fc3f9f361bd02b5e24ee6b773b3.bindPopup(popup_dbe0f338ff4898016053b0135a71e185)
#         ;
#
#
#
#
#             var marker_2fd3db8955c51bcc07329a5ee127706e = L.marker(
#                 [43.7185, 10.401],
#                 {
# }
#             ).addTo(marker_cluster_c22956838da34f80c48a155520380f4f);
#
#
#         var popup_508711475

# %% [markdown]
# # Ciclopi dataset

# %%
path = "https://raw.githubusercontent.com/danielefadda/DVVA_Master/refs/heads/main/Master_2025/folium/data/ciclopi.csv"
df_stations = pd.read_csv(path, sep=";")
# df_stations = pd.read_csv("data/ciclopi.csv", sep =";")
# Create a new dataframe by selecting only the relevant columns
df_stations
# Out:
#              StazPrelievo       StazDeposito  MesePrelievo  Durata
# 0       Vittorio Emanuele      Stazione F.S.            10      39
# 1       Vittorio Emanuele      Stazione F.S.             2      53
# 2       Vittorio Emanuele      Stazione F.S.            10      55
# 3       Vittorio Emanuele      Stazione F.S.            12      56
# 4       Vittorio Emanuele      Stazione F.S.            11      56
# ...                   ...                ...           ...     ...
# 81453               Duomo      Borgo Stretto             3     539
# 81454       Borgo Stretto      Palacongressi             4     539
# 81455               Duomo          Paparelli             2     539
# 81456  Comune Palazzo Blu  Vittorio Emanuele            10     539
# 81457   Vittorio Emanuele              Duomo            10     539
#
# [81458 rows x 4 columns]

# %%
geopath = "https://raw.githubusercontent.com/danielefadda/DVVA_Master/refs/heads/main/Master_2025/folium/data/stazioni_ciclopi.geojson"
geo_stations = gpd.read_file(geopath)
# geo_stations = gpd.read_file("data/stazioni_ciclopi.geojson")
geo_stations
# Out:
#    capacity                name        lon        lat  \
# 0        28       Stazione F.S.  10.398960  43.708471
# 1        16   Vittorio Emanuele  10.398782  43.710185
# 2        24       Palacongressi  10.409712  43.710608
# 3        10           Aeroporto  10.400541  43.698955
# 4        30       Pietrasantina  10.392873  43.729017
# 5        30           Paparelli  10.410243  43.724642
# 6        30             Pratale  10.418427  43.721536
# 7        14       Polo Marzotto  10.407185  43.719803
# 8         9       Borgo Stretto  10.402132  43.718413
# 9        22               Duomo  10.391985  43.722863
# 10       16  Comune Palazzo Blu  10.399895  43.715765
# 11       12      Sms Biblioteca  10.419133  43.706558
# 12       14  Ospedale Cisanello  10.440153  43.706796
# 13       10       Porta a Lucca  10.402260  43.724248
# 14       12    Teatro Tribunale  10.405104  43.716380
#
#                      geometry
# 0   POINT (10.39896 43.70847)
# 1   POINT (10.39878 43.71019)
# 2   POINT (10.40971 43.71061)
# 3   POINT (10.40054 43.69896)
# 4   POINT (10.39287 43.72902)
# 5   POINT (10.41024 43.72464)
# 6   POINT (10.41843 43.72154)
# 7    POINT (10.40718 43.7198)
# 8   POINT (10.40213 43.71841)
# 9   POINT (10.39199 43.72286)
# 10   POINT (10.3999 43.71576)
# 11  POINT (10.41913 43.70656)
# 12   POINT (10.44015 43.7068)
# 13  POINT (10.40226 43.72425)
# 14   POINT (10.4051 43.71638)

# %%
df_stations.columns.tolist()
# Out:
# ['StazPrelievo', 'StazDeposito', 'MesePrelievo', 'Durata']

# %%
count_stazione=df_stations.groupby(by=['MesePrelievo','StazPrelievo']).size().reset_index(name='count')
count_stazione
# Out:
#      MesePrelievo        StazPrelievo  count
# 0               1           Aeroporto     20
# 1               1       Borgo Stretto    988
# 2               1  Comune Palazzo Blu    453
# 3               1               Duomo    453
# 4               1  Ospedale Cisanello      5
# ..            ...                 ...    ...
# 175            12             Pratale    188
# 176            12      Sms Biblioteca     27
# 177            12       Stazione F.S.    719
# 178            12    Teatro Tribunale    293
# 179            12   Vittorio Emanuele    474
#
# [180 rows x 3 columns]

# %%
alt.Chart(count_stazione).mark_line().encode(
      y = alt.Y('count:Q'),
      x = 'MesePrelievo:O',
      color = 'StazPrelievo:N'
      )
# Out:
# alt.Chart(...)

# %%
geo_stations['capacity'] = pd.to_numeric(geo_stations['capacity'], errors='coerce')

alt.Chart(geo_stations).mark_bar().encode(
    y = alt.Y('name:N', sort=alt.EncodingSortField(field='capacity', order='descending')),
    x = 'capacity:Q',
    tooltip=['name:N', 'capacity:Q'],
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(geo_stations).mark_circle().encode(
        longitude = alt.Longitude('lon:Q'),
        latitude = alt.Latitude('lat:Q'),
        size = 'capacity:Q',
        tooltip = ['name:N', 'capacity:Q']
      )
# Out:
# alt.Chart(...)

# %%
m1=folium.Map(location=[43.715765, 10.399895],zoom_start=13)
folium.TileLayer('cartodbpositron').add_to(m1)
folium.LayerControl().add_to(m1)
for index, station in geo_stations.iterrows():
    folium.Marker([station["lat"], station["lon"]], popup=station["name"],icon=folium.Icon(color='darkred', icon='bicycle', prefix='fa')).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bdc3d54e35eb33464220011a9f347d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bdc3d54e35eb33464220011a9f347d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bdc3d54e35eb33464220011a9f347d3 = L.map(
#                 &quot;map_3bdc3d54e35eb33464220011a9f347d3&quot;,
#                 {
#                     center: [43.715765, 10.399895],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4122868f8d9e3eb5f686ffd9288ab38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4122868f8d9e3eb5f686ffd9288ab38.addTo(map_3bdc3d54e35eb33464220011a9f347d3);
#
#
#             var tile_layer_002ea73b82b97f679a8d6458fe78c6cc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_002ea73b82b97f679a8d6458fe78c6cc.addTo(map_3bdc3d54e35eb33464220011a9f347d3);
#
#
#             var layer_control_e2148447971d4d425c7685b7227ff80d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d4122868f8d9e3eb5f686ffd9288ab38,
#                     &quot;cartodbpositron&quot; : tile_layer_002ea73b82b97f679a8d6458fe78c6cc,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_e2148447971d4d425c7685b7227ff80d = L.control.layers(
#                 layer_control_e2148447971d4d425c7685b7227ff80d_layers.base_layers,
#                 layer_control_e2148447971d4d425c7685b7227ff80d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_3bdc3d54e35eb33464220011a9f347d3);
#
#
#
#             var marker_7594234011da9c4a2e4288e5f0259b6c = L.marker(
#                 [43.7084709, 10.3989605],
#                 {
# }
#             ).addTo(map_3bdc3d54e35eb33464220011a9f347d3);
#
#
#             var icon_bec71e04960b71ed6ed3793f2972e4e1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bicycle&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fb3b95f09bba0407a891c31b4c5ff1be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53aa2a419348612536dfe82d1daec574 = $(`&lt;div id=&quot;html_53aa2a419348612536dfe82d1daec574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stazione F.S.&lt;/div&gt;`)[0];
#                 popup_fb3b95f09bba0407a891c31b4c5ff1be.setContent(html_53aa2a419348612536dfe82d1daec574);
#
#
#
#         marker_7594234011da9c4a2e4288e5f0259b6c.bindPopup(popup_fb3b95f09bba0407a891c31b4c5ff1be)
#         ;
#
#
#
#
#                 marker_7594234011da9c4a2e4288e5f0259b6c.setIcon(icon_bec71e04960b71ed6ed3793f2972e4e1);
#
#
#             var marker_da9b0ae2c45e43ff101bd513a2699c49 = L.marker(
#                 [43.7101854, 10.3987825],
#                 {
# }
#             ).addTo(map_3bdc3d54e35eb33464220011a9f347d3);
#
#
#             var icon_4a48899b474652636895f23d30d7dc12 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bicycle&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cf29c5d910cda23070be8d60bf952494 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f687a141e5919daffb1857bc9dd48e9 = $(`&lt;div id=&quot;html_8f687a141e5919daffb1857bc9dd48e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vittorio Emanuele&lt;/div&gt;`)[0];
#                 popup_cf29c5d910cda23070be8d60bf952494.setContent(html_8f687a141e5919daffb1857bc9dd48e9);
#
#
#
#         marker_da9b0ae2c45e43ff101bd513a2699c49.bindPopup(popup_cf29c5d910cda23070be8d60bf952494)
#         ;
#
#
#
#
#                 mar

# %% [markdown]
# a list of availlable icons can be found here: https://fontawesome.com/icons?d=gallery

# %%
# CircleMarker measure is in pixel (scale independent)
# Circle is in meter (scale dependent)

m1=folium.Map(location=[43.715765, 10.399895],zoom_start=13)
for index, station in geo_stations.iterrows():
  viz=alt.Chart(
      count_stazione[count_stazione['StazPrelievo']==station['name']]
      ).mark_line(
          interpolate='monotone',
      ).encode(
      y = alt.Y('count:Q'),
      x = alt.X('MesePrelievo:O').axis(labelAngle=0).title('Months')
      ).properties(width=400).to_dict()

  folium.CircleMarker(
      [station["lat"], station["lon"]],
      popup=folium.Popup(max_width=500).add_child(
        folium.VegaLite(json.dumps(viz), width=500, height=250)
    ),
      radius=10,
      color="darkred",
      fill=True,
      fill_color="#3186cc",
  ).add_to(m1)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28a55becdc474f6c8142e0d951ecd2a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_019825e7a9b8dc1c21fd6bd967937427 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm//vega@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@6&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_lite_5d4d082c7e7da99a9600f9f3ed5bc5dc {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_7e555922f07d97e4911eba7a608f9152 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_77ca5b6035a3ca1df190b29726284d40 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_950d384294186360fc2a8c7e5f10b537 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_553f571833dc9e69cd67bdd1dc45b636 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_c195b58153934e5b2ed2597885b1827a {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_598d6be40a75d8460bd2a9d8596aaeac {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_09c0fc6abd9b4e3c4481b0918bccc86c {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_7757a2ef5fb659898b4e6069f82ff047 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_64ef5fa5a8d69f03c46d4e3cdb14d0d1 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_e179077b6f20af49cb4b21cb9929caf5 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_3fd51cc7b68af1a5604d99a477e66bfd {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_a4e16d84bffc04d39e83264dae5887a8 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_f302454a31b60225f114a206c20d3f80 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28a55becdc474f6c8142e0d951ecd2a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28a55becdc474f6c8142e0d951ecd2a3 = L.map(
#                 &quot;map_28a55becdc474f6c8142e0d951ecd2a3&quot;,
#                 {
#                     center: [43.715765, 10.399895],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5de2e962248015992bfd656026a9c8e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&qu

# %% [markdown]
# # Bonus: Heatmap

# %%
from folium.plugins import HeatMap

# %%
df_stations_start = df_stations[['StazPrelievo']].groupby(['StazPrelievo']).size().reset_index(name='counts')
df_stations_start = pd.merge(df_stations_start, geo_stations, how="inner", left_on=['StazPrelievo'], right_on=['name'])[['StazPrelievo', 'lon', 'lat', 'counts']]

df_stations_end = df_stations[['StazDeposito']].groupby(['StazDeposito']).size().reset_index(name='counts')
df_stations_end = pd.merge(df_stations_end, geo_stations, how="inner", left_on=['StazDeposito'], right_on=['name'])[['StazDeposito', 'lon', 'lat']]

# %%
df_stations_start
# Out:
#           StazPrelievo        lon        lat  counts
# 0            Aeroporto  10.400541  43.698955     183
# 1        Borgo Stretto  10.402132  43.718413   13990
# 2   Comune Palazzo Blu  10.399895  43.715765    6009
# 3                Duomo  10.391985  43.722863    6088
# 4   Ospedale Cisanello  10.440153  43.706796      60
# 5        Palacongressi  10.409712  43.710608    9008
# 6            Paparelli  10.410243  43.724642    4995
# 7        Pietrasantina  10.392873  43.729017    1387
# 8        Polo Marzotto  10.407185  43.719803    9698
# 9        Porta a Lucca  10.402260  43.724248    4066
# 10             Pratale  10.418427  43.721536    3461
# 11      Sms Biblioteca  10.419133  43.706558     751
# 12       Stazione F.S.  10.398960  43.708471   10348
# 13    Teatro Tribunale  10.405104  43.716380    4464
# 14   Vittorio Emanuele  10.398782  43.710185    6950

# %%
df_stations_start[['lat', 'lon','counts']].values.tolist()
# Out:
# [[43.6989552, 10.4005415, 183.0],
#  [43.7184126, 10.4021322, 13990.0],
#  [43.7157647, 10.3998955, 6009.0],
#  [43.7228627, 10.3919852, 6088.0],
#  [43.7067956, 10.4401533, 60.0],
#  [43.7106075, 10.4097121, 9008.0],
#  [43.7246423, 10.410243, 4995.0],
#  [43.7290165, 10.3928733, 1387.0],
#  [43.7198029, 10.4071847, 9698.0],
#  [43.7242476, 10.4022602, 4066.0],
#  [43.7215365, 10.4184265, 3461.0],
#  [43.7065577, 10.4191334, 751.0],
#  [43.7084709, 10.3989605, 10348.0],
#  [43.7163803, 10.4051037, 4464.0],
#  [43.7101854, 10.3987825, 6950.0]]

# %%
# m1=folium.Map(location=[43.715765, 10.399895],zoom_start=13)
HeatMap(data=df_stations_start[['lat', 'lon','counts']].values.tolist(),radius=30, max_zoom=13).add_to(m1)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28a55becdc474f6c8142e0d951ecd2a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_019825e7a9b8dc1c21fd6bd967937427 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm//vega@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@6&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_lite_5d4d082c7e7da99a9600f9f3ed5bc5dc {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_7e555922f07d97e4911eba7a608f9152 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_77ca5b6035a3ca1df190b29726284d40 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_950d384294186360fc2a8c7e5f10b537 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_553f571833dc9e69cd67bdd1dc45b636 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_c195b58153934e5b2ed2597885b1827a {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_598d6be40a75d8460bd2a9d8596aaeac {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_09c0fc6abd9b4e3c4481b0918bccc86c {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_7757a2ef5fb659898b4e6069f82ff047 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_64ef5fa5a8d69f03c46d4e3cdb14d0d1 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_e179077b6f20af49cb4b21cb9929caf5 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_3fd51cc7b68af1a5604d99a477e66bfd {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_a4e16d84bffc04d39e83264dae5887a8 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_f302454a31b60225f114a206c20d3f80 {
#                 position : relative;
#                 width : 500.0px;
#                 height: 250.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28a55becdc474f6c8142e0d951ecd2a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28a55becdc474f6c8142e0d951ecd2a3 = L.map(
#                 &quot;map_28a55becdc474f6c8142e0d951ecd2a3&quot;,
#                 {
#                     center: [43.715765, 10.399895],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5de2e962248015992bfd656026a9c8e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attr
